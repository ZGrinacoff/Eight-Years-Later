# %%
import pandas as pd

# %%
# All work on my graph was done on plot.ly I have provided the code but it doesnt appear to be useable in matplotlib
import matplotlib.pyplot as plt

# %%
import requests

import numpy as np

# %%
from census import Census
from us import states
api_key="a544ed666174bd3c629d4825ae204add4751785c"

# %%
# this was census data I dont know why but all degress and eductaion above Bachelors did not work

# %%
c = Census(api_key, year=2009)
census_data = c.acs5.get(("NAME","B15003_017E", "B15003_022E","B01003_001E","B15003_019E","B15003_021E",), {'for': 'state:*'})
census_df = pd.DataFrame(census_data)

census_df = census_df.rename(columns={"B15003_017E": "Education: High School","B01003_001E": "Total Population",
                                      "B15003_022E": "Education: Bachelors","B15003_019E":"Some college, less than 1 year",
                                      "B15003_021E":"Associate's degree",
                                      "NAME": "State", "state": "State Number"})
census_df['Share of Population with HS Diploma'] = 1 - \
    census_df['Education: High School'].astype(
        int) / census_df['Total Population'].astype(int)


census_df["Some college, less than 1 year"] = 1 - \
    census_df["Some college, less than 1 year"].astype(
        int) / census_df['Education: High School'].astype(int)

census_df["Associate's degree"] = 1 - \
    census_df["Associate's degree"].astype(
        int) / census_df['Education: High School'].astype(int)

census_df['Share of Population with Bachelors'] =  1- \
    census_df['Education: Bachelors'].astype(
        int) / census_df["Total Population"].astype(int)

census_df = census_df[["State", "Total Population","Share of Population with HS Diploma","Share of Population with Bachelors",
                       "Some college, less than 1 year","Associate's degree"]]

# %%
df=pd.read_csv("hate_crime_socioeconomic_2017.csv")

df.head()

ppf=df['Poverty Rate']

zf=df["Hate Crime Rate"]

rf=df["Share of Population with HS Diploma"]*100

sf=df["State"]

interactive3df=pd.DataFrame({"State":sf, "Share of Population with HS Diploma":rf, "Hate Crime Rate":zf})

interactive3df.to_csv("interactive3df.csv")

# %%
ddf=pd.read_csv("hate_crime_socioeconomic_2009.csv")

ddf.head()

wf=ddf['State']
ef=ddf['Share of Population with HS Diploma']*100
yf=ddf['Hate Crime Rate']
wwf=ddf["Poverty Rate"]

idf=pd.DataFrame({"State":wf, "Share of Population with HS Diploma":ef, "Hate Crime Rate":yf})

idf.to_csv("idf.csv")

# %%
# Plotly matlab dont know why it wont work in the notebook.Does not contain Regressions.
% Get this figure: fig = getplotlyfig('maximusrex', 10)
% Get this figure's data: fig = getplotlyfig('maximusrex', 10); fig.data
% Add data to this figure: plotly([1, 2], [2, 3], struct('filename', 'Plot 10', 'fileopt', 'extend'))
% Get y data of first trace: fig = getplotlyfig('maximusrex', 10); y1 = fig.data{1}.y

% Get figure documentation: https://plot.ly/matlab/get-requests/
% Add data documentation: https://plot.ly/matlab/file-options/

% You can reproduce this figure in MATLAB with the following code!

% Learn about API authentication here: https://plot.ly/matlab/getting-started
% Find your api_key here: https://plot.ly/settings/api

signin('username','b6MpKUAsC2kPmWLoBYJq' )
trace1 = struct(...
  'uid', '5076f6', ...
  'meta', struct('columnNames', struct(...
      'x', 'Share of Population with HS Diploma', ...
      'y', 'Hate Crime Rate', ...
  'hoverinfo', 'y+text', ...
  'stackgroup', NaN);
data = {trace1, trace2};
layout = struct(...
  'title', struct('text', ''), ...
  'xaxis', struct(...
    'type', 'linear', ...
    'range', [75.63006545691128, 89.53904645600055], ...
    'title', struct('text', 'Population with high school diploma(%)'), ...
    'autorange', false), ...
  'yaxis', struct(...
    'type', 'linear', ...
    'range', [-6.466025442134658, 40], ...
    'title', struct('text', 'Hate crime rate per 100,00'), ...
    'autorange', false), ...
  'modebar', struct('color', 'rgba(214, 116, 116, 0.3)'), ...
  'autosize', true, ...
  'dragmode', 'zoom', ...
  'template', struct(...
    'data', struct(...
      'bar', { {...
        struct(...
          'type', 'bar', ...
          'marker', struct('colorbar', struct(...
              'ticks', '', ...
              'outlinewidth', 0)))...
      } }, ...
      'table', { {...
        struct(...
          'type', 'table', ...
          'cells', struct(...
            'fill', struct('color', '#EBF0F8'), ...
            'line', struct('color', 'white')), ...
          'header', struct(...
            'fill', struct('color', '#C8D4E3'), ...
            'line', struct('color', 'white')))...
      } }, ...
      'carpet', { {...
        struct(...
          'type', 'carpet', ...
          'aaxis', struct(...
            'gridcolor', '#C8D4E3', ...
            'linecolor', '#C8D4E3', ...
            'endlinecolor', '#2a3f5f', ...
            'minorgridcolor', '#C8D4E3', ...
            'startlinecolor', '#2a3f5f'), ...
          'baxis', struct(...
            'gridcolor', '#C8D4E3', ...
            'linecolor', '#C8D4E3', ...
            'endlinecolor', '#2a3f5f', ...
            'minorgridcolor', '#C8D4E3', ...
            'startlinecolor', '#2a3f5f'))...
      } }, ...
      'mesh3d', { {...
        struct(...
          'type', 'mesh3d', ...
          'colorbar', struct(...
            'ticks', '', ...
            'outlinewidth', 0))...
      } }, ...
      'contour', { {...
        struct(...
          'type', 'contour', ...
          'colorbar', struct(...
            'ticks', '', ...
            'outlinewidth', 0), ...
          'autocolorscale', true)...
      } }, ...
      'heatmap', { {...
        struct(...
          'type', 'heatmap', ...
          'colorbar', struct(...
            'ticks', '', ...
            'outlinewidth', 0), ...
          'autocolorscale', true)...
      } }, ...
      'scatter', { {...
        struct(...
          'type', 'scatter', ...
          'marker', struct('colorbar', struct(...
              'ticks', '', ...
              'outlinewidth', 0)))...
      } }, ...
      'surface', { {...
        struct(...
          'type', 'surface', ...
          'colorbar', struct(...
            'ticks', '', ...
            'outlinewidth', 0))...
      } }, ...
      'heatmapgl', { {...
        struct(...
          'type', 'heatmapgl', ...
          'colorbar', struct(...
            'ticks', '', ...
            'outlinewidth', 0))...
      } }, ...
      'histogram', { {...
        struct(...
          'type', 'histogram', ...
          'marker', struct('colorbar', struct(...
              'ticks', '', ...
              'outlinewidth', 0)))...
      } }, ...
      'parcoords', { {...
        struct(...
          'line', struct('colorbar', struct(...
              'ticks', '', ...
              'outlinewidth', 0)), ...
          'type', 'parcoords')...
      } }, ...
      'scatter3d', { {...
        struct(...
          'type', 'scatter3d', ...
          'marker', struct('colorbar', struct(...
              'ticks', '', ...
              'outlinewidth', 0)))...
      } }, ...
      'scattergl', { {...
        struct(...
          'type', 'scattergl', ...
          'marker', struct('colorbar', struct(...
              'ticks', '', ...
              'outlinewidth', 0)))...
      } }, ...
      'choropleth', { {...
        struct(...
          'type', 'choropleth', ...
          'colorbar', struct(...
            'ticks', '', ...
            'outlinewidth', 0))...
      } }, ...
      'scattergeo', { {...
        struct(...
          'type', 'scattergeo', ...
          'marker', struct('colorbar', struct(...
              'ticks', '', ...
              'outlinewidth', 0)))...
      } }, ...
      'histogram2d', { {...
        struct(...
          'type', 'histogram2d', ...
          'colorbar', struct(...
            'ticks', '', ...
            'outlinewidth', 0), ...
          'autocolorscale', true)...
      } }, ...
      'scatterpolar', { {...
        struct(...
          'type', 'scatterpolar', ...
          'marker', struct('colorbar', struct(...
              'ticks', '', ...
              'outlinewidth', 0)))...
      } }, ...
      'contourcarpet', { {...
        struct(...
          'type', 'contourcarpet', ...
          'colorbar', struct(...
            'ticks', '', ...
            'outlinewidth', 0))...
      } }, ...
      'scattercarpet', { {...
        struct(...
          'type', 'scattercarpet', ...
          'marker', struct('colorbar', struct(...
              'ticks', '', ...
              'outlinewidth', 0)))...
      } }, ...
      'scattermapbox', { {...
        struct(...
          'type', 'scattermapbox', ...
          'marker', struct('colorbar', struct(...
              'ticks', '', ...
              'outlinewidth', 0)))...
      } }, ...
      'scatterpolargl', { {...
        struct(...
          'type', 'scatterpolargl', ...
          'marker', struct('colorbar', struct(...
              'ticks', '', ...
              'outlinewidth', 0)))...
      } }, ...
      'scatterternary', { {...
        struct(...
          'type', 'scatterternary', ...
          'marker', struct('colorbar', struct(...
              'ticks', '', ...
              'outlinewidth', 0)))...
      } }, ...
      'histogram2dcontour', { {...
        struct(...
          'type', 'histogram2dcontour', ...
          'colorbar', struct(...
            'ticks', '', ...
            'outlinewidth', 0), ...
          'autocolorscale', true)...
      } }), ...
    'layout', struct(...
      'geo', struct(...
        'bgcolor', 'white', ...
        'showland', true, ...
        'lakecolor', 'white', ...
        'landcolor', 'white', ...
        'showlakes', true, ...
        'subunitcolor', '#C8D4E3'), ...
      'font', struct('color', '#2a3f5f'), ...
      'polar', struct(...
        'bgcolor', 'white', ...
        'radialaxis', struct(...
          'ticks', '', ...
          'gridcolor', '#EBF0F8', ...
          'linecolor', '#EBF0F8'), ...
        'angularaxis', struct(...
          'ticks', '', ...
          'gridcolor', '#EBF0F8', ...
          'linecolor', '#EBF0F8')), ...
      'scene', struct(...
        'xaxis', struct(...
          'ticks', '', ...
          'gridcolor', '#DFE8F3', ...
          'gridwidth', 2, ...
          'linecolor', '#EBF0F8', ...
          'zerolinecolor', '#EBF0F8', ...
          'showbackground', true, ...
          'backgroundcolor', 'white'), ...
        'yaxis', struct(...
          'ticks', '', ...
          'gridcolor', '#DFE8F3', ...
          'gridwidth', 2, ...
          'linecolor', '#EBF0F8', ...
          'zerolinecolor', '#EBF0F8', ...
          'showbackground', true, ...
          'backgroundcolor', 'white'), ...
        'zaxis', struct(...
          'ticks', '', ...
          'gridcolor', '#DFE8F3', ...
          'gridwidth', 2, ...
          'linecolor', '#EBF0F8', ...
          'zerolinecolor', '#EBF0F8', ...
          'showbackground', true, ...
          'backgroundcolor', 'white')), ...
      'title', struct('x', 0.05), ...
      'xaxis', struct(...
        'ticks', '', ...
        'gridcolor', '#EBF0F8', ...
        'linecolor', '#EBF0F8', ...
        'automargin', true, ...
        'zerolinecolor', '#EBF0F8', ...
        'zerolinewidth', 2), ...
      'yaxis', struct(...
        'ticks', '', ...
        'gridcolor', '#EBF0F8', ...
        'linecolor', '#EBF0F8', ...
        'automargin', true, ...
        'zerolinecolor', '#EBF0F8', ...
        'zerolinewidth', 2), ...
      'ternary', struct(...
        'aaxis', struct(...
          'ticks', '', ...
          'gridcolor', '#DFE8F3', ...
          'linecolor', '#A2B1C6'), ...
        'baxis', struct(...
          'ticks', '', ...
          'gridcolor', '#DFE8F3', ...
          'linecolor', '#A2B1C6'), ...
        'caxis', struct(...
          'ticks', '', ...
          'gridcolor', '#DFE8F3', ...
          'linecolor', '#A2B1C6'), ...
        'bgcolor', 'white'), ...
      'colorway', { {'#636efa', '#EF553B', '#00cc96', '#ab63fa', '#19d3f3', '#e763fa', '#fecb52', '#ffa15a', '#ff6692', '#b6e880'} }, ...
      'hovermode', 'closest', ...
      'colorscale', struct(...
        'diverging', { { {0, '#8e0152'},{0.1, '#c51b7d'},{0.2, '#de77ae'},{0.3, '#f1b6da'},{0.4, '#fde0ef'},{0.5, '#f7f7f7'},{0.6, '#e6f5d0'},{0.7, '#b8e186'},{0.8, '#7fbc41'},{0.9, '#4d9221'},{1, '#276419'} } }, ...
        'sequential', { { {0, '#0508b8'},{0.0893854748603352, '#1910d8'},{0.1787709497206704, '#3c19f0'},{0.2681564245810056, '#6b1cfb'},{0.3575418994413408, '#981cfd'},{0.44692737430167595, '#bf1cfd'},{0.5363128491620112, '#dd2bfd'},{0.6256983240223464, '#f246fe'},{0.7150837988826816, '#fc67fd'},{0.8044692737430168, '#fe88fc'},{0.8938547486033519, '#fea5fd'},{0.9832402234636871, '#febefe'},{1, '#fec3fe'} } }, ...
        'sequentialminus', { { {0, '#0508b8'},{0.0893854748603352, '#1910d8'},{0.1787709497206704, '#3c19f0'},{0.2681564245810056, '#6b1cfb'},{0.3575418994413408, '#981cfd'},{0.44692737430167595, '#bf1cfd'},{0.5363128491620112, '#dd2bfd'},{0.6256983240223464, '#f246fe'},{0.7150837988826816, '#fc67fd'},{0.8044692737430168, '#fe88fc'},{0.8938547486033519, '#fea5fd'},{0.9832402234636871, '#febefe'},{1, '#fec3fe'} } }), ...
      'plot_bgcolor', 'white', ...
      'paper_bgcolor', 'white', ...
      'shapedefaults', struct(...
        'line', struct('width', 0), ...
        'opacity', 0.4, ...
        'fillcolor', '#506784'), ...
      'annotationdefaults', struct(...
        'arrowhead', 0, ...
        'arrowcolor', '#506784', ...
        'arrowwidth', 1)), ...
    'themeRef', 'PLOTLY_WHITE'), ...
  'clickmode', 'event', ...
  'hovermode', 'closest', ...
  'showlegend', true, ...
  'annotations', { {...
    struct(...
      'x', 81.92759025313924, ...
      'y', 208.33333333333331, ...
      'font', struct('size', 15), ...
      'text', '', ...
      'arrowcolor', 'rgb(80, 132, 121)')...
  } });
response = plotly(data, struct('layout', layout));
plot_url = response.url
